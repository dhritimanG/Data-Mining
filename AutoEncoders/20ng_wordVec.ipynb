# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Fri Mar 30 11:02:09 2018

@author: dhritiman
"""

#!/usr/bin/env python2
# -*- coding: utf-8 -*-
"""
Created on Wed Mar 21 14:30:39 2018

@author: dhritiman
"""

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import sys
import argparse
import random
from tempfile import gettempdir
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

from tensorflow.contrib.tensorboard.plugins import projector


current_path = '/Users/dhritiman/.spyder'

parser = argparse.ArgumentParser()
parser.add_argument(
    '--log_dir',
    type=str,
    default=os.path.join(current_path, 'log'),
    help='The log directory for TensorBoard summaries.')
FLAGS, unparsed = parser.parse_known_args()

# Create the directory for TensorBoard variables if there is not.
if not os.path.exists(FLAGS.log_dir):
  os.makedirs(FLAGS.log_dir)

# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'

# 20 NG

from sklearn.datasets import fetch_20newsgroups
newsgroups_train = fetch_20newsgroups(subset='train')
newsgroups_test = fetch_20newsgroups(subset='test')

from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer()
vectorizer.fit(newsgroups_train.data)
vectors_train = vectorizer.transform(newsgroups_train.data)
vectors_test = vectorizer.transform(newsgroups_test.data)

# NG LABELS
train_labels = newsgroups_train.target
test_labels = newsgroups_test.target


NG_all = fetch_20newsgroups(subset = 'all')
corpus = ''

for i in range(len(NG_all.data)):
    corpus += NG_all.data[i]
    corpus += ' '
vocabulary = corpus.split()

vocabulary_size = 50000


def build_dataset(words, n_words):
  """Process raw inputs into a dataset."""
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(n_words - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    index = dictionary.get(word, 0)
    if index == 0:  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reversed_dictionary


# Filling 4 global variables:
# data - list of codes (integers from 0 to vocabulary_size-1).
#   This is the original text but words are replaced by their codes
# count - map of words(strings) to count of occurrences
# dictionary - map of words(strings) to their codes(integers)
# reverse_dictionary - maps codes(integers) to words(strings)
data, count, dictionary, reverse_dictionary = build_dataset(
    vocabulary, vocabulary_size)

del vocabulary

print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0




# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)  # pylint: disable=redefined-builtin
  if data_index + span > len(data):
    data_index = 0
  buffer.extend(data[data_index:data_index + span])
  data_index += span
  for i in range(batch_size // num_skips):
    context_words = [w for w in range(span) if w != skip_window]
    words_to_use = random.sample(context_words, num_skips)
    for j, context_word in enumerate(words_to_use):
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[context_word]
    if data_index == len(data):
      buffer.extend(data[0:span])
      data_index = span
    else:
      buffer.append(data[data_index])
      data_index += 1
  # Backtrack a little bit to avoid skipping words in the end of a batch
  data_index = (data_index + len(data) - span) % len(data)
  return batch, labels


batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]], '->', labels[i, 0],
        reverse_dictionary[labels[i, 0]])









# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1  # How many words to consider left and right.
num_skips = 2  # How many times to reuse an input to generate a label.
num_sampled = 64  # Number of negative examples to sample.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. These 3 variables are used only for
# displaying model accuracy, they don't affect calculation.
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)

graph = tf.Graph()

with graph.as_default():

  # Input data.
  with tf.name_scope('inputs'):
    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    with tf.name_scope('embeddings'):
      embeddings = tf.Variable(
          tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
      embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    with tf.name_scope('weights'):
      nce_weights = tf.Variable(
          tf.truncated_normal(
              [vocabulary_size, embedding_size],
              stddev=1.0 / math.sqrt(embedding_size)))
    with tf.name_scope('biases'):
      nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  # Explanation of the meaning of NCE loss:
  #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
  with tf.name_scope('loss'):
    loss = tf.reduce_mean(
        tf.nn.nce_loss(
            weights=nce_weights,
            biases=nce_biases,
            labels=train_labels,
            inputs=embed,
            num_sampled=num_sampled,
            num_classes=vocabulary_size))

  # Add the loss value as a scalar to summary.
  tf.summary.scalar('loss', loss)

  # Construct the SGD optimizer using a learning rate of 1.0.
  with tf.name_scope('optimizer'):
    optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings,
                                            valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Merge all summaries.
  merged = tf.summary.merge_all()

  # Add variable initializer.
  init = tf.global_variables_initializer()

  # Create a saver.
  saver = tf.train.Saver()

# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
  # Open a writer to write summaries.
  writer = tf.summary.FileWriter(FLAGS.log_dir, session.graph)

  # We must initialize all variables before we use them.
  init.run()
  print('Initialized')

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(batch_size, num_skips,
                                                skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # Define metadata variable.
    run_metadata = tf.RunMetadata()

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    # Also, evaluate the merged op to get all summaries from the returned "summary" variable.
    # Feed metadata variable to session for visualizing the graph in TensorBoard.
    _, summary, loss_val = session.run(
        [optimizer, merged, loss],
        feed_dict=feed_dict,
        run_metadata=run_metadata)
    average_loss += loss_val

    # Add returned summaries to writer in each step.
    writer.add_summary(summary, step)
    # Add metadata to visualize the graph for the last run.
    if step == (num_steps - 1):
      writer.add_run_metadata(run_metadata, 'step%d' % step)

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step ', step, ': ', average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = '%s %s,' % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()

  # Write corresponding labels for the embeddings.
  with open(FLAGS.log_dir + '/metadata.tsv', 'w') as f:
    for i in xrange(vocabulary_size):
      f.write(reverse_dictionary[i] + '\n')

  # Save the model for checkpoints.
  saver.save(session, os.path.join(FLAGS.log_dir, 'model.ckpt'))

  # Create a configuration for visualizing embeddings with the labels in TensorBoard.
  config = projector.ProjectorConfig()
  embedding_conf = config.embeddings.add()
  embedding_conf.tensor_name = embeddings.name
  embedding_conf.metadata_path = os.path.join(FLAGS.log_dir, 'metadata.tsv')
  projector.visualize_embeddings(writer, config)

writer.close()

# Step 6: Visualize the embeddings.


# pylint: disable=missing-docstring
# Function to draw visualization of distance between embeddings.
def plot_with_labels(low_dim_embs, labels, filename):
  assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
  plt.figure(figsize=(18, 18))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(
        label,
        xy=(x, y),
        xytext=(5, 2),
        textcoords='offset points',
        ha='right',
        va='bottom')

  plt.savefig(filename)


try:
  # pylint: disable=g-import-not-at-top
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(
      perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
  plot_only = 500
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
  labels = [reverse_dictionary[i] for i in xrange(plot_only)]
  plot_with_labels(low_dim_embs, labels, os.path.join(gettempdir(), 'tsne.png'))

except ImportError as ex:
  print('Please install sklearn, matplotlib, and scipy to show embeddings.')
  print(ex)
# Out:
# Most common words (+UNK) [['UNK', 567715], ('the', 210209), ('to', 115712), ('of', 110387), ('a', 92635)]
# Sample data [26, 27940, 27941, 23338, 27942, 25, 3262, 1494, 6751, 28] ['From:', 'Mamatha', 'Devineni', 'Ratnam', '<mr47+@andrew.cmu.edu>', 'Subject:', 'Pens', 'fans', 'reactions', 'Organization:']
# 27940 Mamatha -> 26 From:
# 27940 Mamatha -> 27941 Devineni
# 27941 Devineni -> 27940 Mamatha
# 27941 Devineni -> 23338 Ratnam
# 23338 Ratnam -> 27941 Devineni
# 23338 Ratnam -> 27942 <mr47+@andrew.cmu.edu>
# 27942 <mr47+@andrew.cmu.edu> -> 25 Subject:
# 27942 <mr47+@andrew.cmu.edu> -> 23338 Ratnam
# Initialized
# Average loss at step  0 :  249.337280273
# Nearest to only: Team., (5-1/4", Receiver, totalitarian, PRESIDENT, inception, stand-alone, mph,,
# Nearest to that: valley, 19:, regulations, whatsoever, Sr., CGY, vs., listening?,
# Nearest to would: scratching, >Q:, schedule,, enemy, MS., Dionne, sail, congressman,
# Nearest to can: graphing, premium, dictionary, Window., above_, ATF., netland, license,
# Nearest to at: ahead, replaced, homosexuality, labelling, infant, invasion,, HST, +5,
# Nearest to has: raid?, SMARTDRV, Israel's, overthrow, pen, 'hacker', pins, Hardly,
# Nearest to use: despite, Recurrent, XLH, monogamous, Siemens-Nixdorf, gold., 173, 16,000,
# Nearest to Organization:: AF, sh:, dollars,, physicians, Achkar), ndet_loop.c:, Ca,, Speak,
# Nearest to your: drug?, Estimating, content., yours., ipser@solomon.technet.sg, feelings., breaking, banging,
# Nearest to we: MOVE, 90., BOOKS, stretching, apologists., caralv@caralv.auto-trol.com, MRA, insights,
# Nearest to -: quibble, 75., globally, admit, colds,, traer, Molotov, HB,
# Nearest to an: occupation., illusions, n., StyleWriter, Purchased, endangered, parliamentary, ________________________________________________________________________________,
# Nearest to as: 392,, Sternberg), Babcock), league,, just, printed, marched, won.,
# Nearest to you: differs, mechanics, auto, Missions, Lau), unbiased, mail-order, gratification,
# Nearest to I'm: Wide, instructions., damages., Fortran, Everyone, Berson, adhesive?, (Technical,
# Nearest to been: jmh@hopper.Virginia.EDU, real, Latina), *********************************************************************, divide,, ART, fault,, sporting,
# Average loss at step  2000 :  121.926405365
# Average loss at step  4000 :  57.813248116
# Average loss at step  6000 :  35.858897238
# Average loss at step  8000 :  40.1442805929
# Average loss at step  10000 :  20.4499647427
# Nearest to only: UNK, DeCenso, PRESIDENT, control., and, students, strength, conclusions.,
# Nearest to that: and, to, UNK, we, you, I, the, not,
# Nearest to would: to, a, been, could, I, you, may, can,
# Nearest to can: to, may, will, would, UNK, and, could, should,
# Nearest to at: in, carrier., ahead, HST, UNK, Card), from, grips,
# Nearest to has: is, 73, ndet_loop.c:687:, life,, X-Force, Flyby, everyone, pins,
# Nearest to use: despite, Mattingly, Card), X*), individuals, Flight, servicemen, deserved,
# Nearest to Organization:: UNK, Ca,, letter, lot,, Messianic, Lines:, alone, X*),
# Nearest to your: the, UNK, feelings., any, %d, xterm-map, char, (Mika,
# Nearest to we: I, you, they, the, not, and, been, UNK,
# Nearest to -: UNK, Settings, and, g3states.h, Before, SALE, HDD/FDD, Don,
# Nearest to an: the, a, to, UNK, and, any, I, been,
# Nearest to as: UNK, and, just, in, to, Mattingly, with, Clemson,
# Nearest to you: I, we, they, the, it, be, and, a,
# Nearest to I'm: Wide, Everyone, largely, [PTS], UNK, e-mail:, Fatal, Ghostview,
# Nearest to been: a, to, I, the, we, would, you, who,
# Average loss at step  12000 :  17.2556562564
# Average loss at step  14000 :  15.4705286562
# Average loss at step  16000 :  21.2704088764
# Average loss at step  18000 :  10.7154509921
# Average loss at step  20000 :  39.4479897991
# Nearest to only: had, DeCenso, should, probably, control., all, anybody, PRESIDENT,
# Nearest to that: and, but, in, what, if, as, which, who,
# Nearest to would: could, can, should, will, to, may, that, and,
# Nearest to can: to, should, will, and, would, could, may, know,
# Nearest to at: in, on, of, from, to, carrier., for, and,
# Nearest to has: is, was, have, 73, everyone, life,, raid?, ndet_loop.c:687:,
# Nearest to use: despite, make, Siemens-Nixdorf, Flight, >, Mattingly, individuals, deserved,
# Nearest to Organization:: Achkar), We, Distribution:, State, lot,, Lines:, -, talk.politics.guns,
# Nearest to your: the, my, a, any, an, one, this, his,
# Nearest to we: I, you, they, not, You, it, just, ../.././lib/Xmu/libXmu.a,
# Nearest to -: and, o&o>, |>, 66.66, *p, BR>, in, <o&o,
# Nearest to an: the, a, your, his, me, it, to, my,
# Nearest to as: in, and, that, just, when, were, with, UNK,
# Nearest to you: I, they, we, it, to, the, people, gone,
# Nearest to I'm: Wide, instructions., largely, Everyone, (Technical, then, Tea, tools.,
# Nearest to been: a, real, (matthew, and, had, I, to, everyone,
# Average loss at step  22000 :  10.8002966416
# Average loss at step  24000 :  9.20362008572
# Average loss at step  26000 :  11.7755962331
# Average loss at step  28000 :  10.9673179671
# Average loss at step  30000 :  7.06076687151
# Nearest to only: no, all, UNK, that, should, and, anybody, PRESIDENT,
# Nearest to that: which, who, and, in, not, you, there, they,
# Nearest to would: will, could, can, should, may, might, doesn't, must,
# Nearest to can: will, should, would, could, may, cannot, to, didn't,
# Nearest to at: in, from, on, and, for, to, into, of,
# Nearest to has: is, have, was, 'hacker', -$10, had, does, Michelle,
# Nearest to use: make, way, despite, end, >, Siemens-Nixdorf, individuals, kill,
# Nearest to Organization:: Achkar), Nntp-Posting-Host:, Distribution:, other;, We, Lines:, talk.politics.guns, State,
# Nearest to your: my, the, any, his, this, an, a, our,
# Nearest to we: you, I, they, not, there, it, he, They,
# Nearest to -: MVI, Settings, and, BR>, o&o>, but, <o&o, 0.36,
# Nearest to an: the, a, my, your, his, just, it, to,
# Nearest to as: and, just, so, very, with, or, for, time,
# Nearest to you: they, we, there, I, not, it, who, people,
# Nearest to I'm: is, Wide, instructions., (Technical, am, Everyone, largely, tools.,
# Nearest to been: had, real, was, (matthew, is, it's, K(>, everyone,
# Average loss at step  32000 :  22.1803799916
# Average loss at step  34000 :  6.98503323555
# Average loss at step  36000 :  6.6863512696
# Average loss at step  38000 :  5.80693510121
# Average loss at step  40000 :  13.4950216626
# Nearest to only: also, no, all, which, that, UNK, still, always,
# Nearest to that: which, and, in, also, UNK, what, this, to,
# Nearest to would: will, can, could, should, may, must, might, doesn't,
# Nearest to can: will, would, should, could, may, cannot, didn't, might,
# Nearest to at: in, on, from, and, for, to, with, invasion,,
# Nearest to has: is, was, have, had, 'hacker', Michelle, does, -$10,
# Nearest to use: make, end, convert, despite, way, individuals, kill, find,
# Nearest to Organization:: Nntp-Posting-Host:, Achkar), Distribution:, State, other;, talk.politics.guns, We, 75.6,
# Nearest to your: my, the, any, his, this, their, our, a,
# Nearest to we: they, you, I, there, We, it, You, not,
# Nearest to -: , STA, List:, k/sec, MVI, gb>, o&o>, [==],
# Nearest to an: the, your, my, a, his, also, just, some,
# Nearest to as: very, and, for, so, with, in, that, just,
# Nearest to you: we, they, I, there, it, people, not, You,
# Nearest to I'm: am, you're, Wide, instructions., (Technical, they're, it's, is,
# Nearest to been: had, was, be, (matthew, real, K(>, everyone, were,
# Average loss at step  42000 :  7.43412626338
# Average loss at step  44000 :  5.61995694578
# Average loss at step  46000 :  5.37030689454
# Average loss at step  48000 :  5.82937978905
# Average loss at step  50000 :  5.19393703008
# Nearest to only: no, also, all, probably, which, UNK, that, women,
# Nearest to that: which, what, and, before, who, all, in, as,
# Nearest to would: will, can, could, should, may, might, must, didn't,
# Nearest to can: will, could, would, should, cannot, may, might, didn't,
# Nearest to at: in, on, from, for, with, invasion,, into, and,
# Nearest to has: is, was, had, have, 'hacker', does, Michelle, Hardly,
# Nearest to use: make, end, despite, convert, way, kill, UNK, individuals,
# Nearest to Organization:: Nntp-Posting-Host:, Achkar), Distribution:, State, Reply-To:, other;, We, talk.politics.guns,
# Nearest to your: my, the, his, their, any, our, a, this,
# Nearest to we: they, you, I, You, he, We, it, there,
# Nearest to -: Settings, current., up,, television., 00-00, bisexual, WIN, successive,
# Nearest to an: the, your, his, Sexual, my, players, all", advantage,
# Nearest to as: and, when, very, in, that, so, against, from,
# Nearest to you: we, they, I, someone, You, it, people, gone,
# Nearest to I'm: am, you're, it's, they're, tools., instructions., Wide, (Technical,
# Nearest to been: had, was, be, were, already, (matthew, also, K(>,
# Average loss at step  52000 :  4.97834114289
# Average loss at step  54000 :  13.5286954397
# Average loss at step  56000 :  5.01099216747
# Average loss at step  58000 :  9.86087621657
# Average loss at step  60000 :  7.99385821033
# Nearest to only: /lib/libX11.so, also, 0.067, TEL, 0.000, , no, X*),
# Nearest to that: which, what, before, >that, ../.././lib/Xmu/libXmu.a, <o&o, and, EQU,
# Nearest to would: will, should, can, could, may, must, might, doesn't,
# Nearest to can: will, could, should, would, cannot, may, might, can't,
# Nearest to at: in, on, from, invasion,, into, over, for, invoke,
# Nearest to has: is, had, was, have, 'hacker', does, -$10, Michelle,
# Nearest to use: make, end, convert, individuals, kill, despite, /--, find,
# Nearest to Organization:: Nntp-Posting-Host:, Achkar), Reply-To:, Distribution:, State, talk.politics.guns, other;, We,
# Nearest to your: my, his, the, their, any, our, this, a,
# Nearest to we: they, you, I, You, he, We, it, there,
# Nearest to -: Settings, 00-00, SALE, television., up,, current., Gm, before,
# Nearest to an: your, the, Sexual, all", his, Church,, my, advantage,
# Nearest to as: and, very, when, As, PIT,, so, since, like,
# Nearest to you: we, they, I, someone, You, it, people, i,
# Nearest to I'm: you're, it's, am, they're, tools., Wide, is, instructions.,
# Nearest to been: had, be, was, already, were, jmh@hopper.Virginia.EDU, (matthew, also,
# Average loss at step  62000 :  5.60420622456
# Average loss at step  64000 :  8.3460631305
# Average loss at step  66000 :  5.16321655202
# Average loss at step  68000 :  24.9236489699
# Average loss at step  70000 :  11.3009106768
# Nearest to only: also, no, probably, best, students, which, all, anybody,
# Nearest to that: which, what, also, ../.././lib/Xmu/libXmu.a, EQU, >that, <o&o, before,
# Nearest to would: will, should, can, could, may, must, might, didn't,
# Nearest to can: will, could, should, would, cannot, may, might, can't,
# Nearest to at: in, from, on, invasion,, for, with, into, over,
# Nearest to has: had, is, was, have, does, 'hacker', I've, Hardly,
# Nearest to use: end, individuals, make, kill, convert, /--, way, 0.067,
# Nearest to Organization:: Nntp-Posting-Host:, Achkar), Reply-To:, Distribution:, State, talk.politics.guns, other;, 75.6,
# Nearest to your: my, his, their, the, our, any, a, its,
# Nearest to we: they, you, I, he, You, We, it, OO,
# Nearest to -: [==], 00-00, Settings, Winner, champ,, /lib/libX11.so, 0.36, MVI,
# Nearest to an: your, Sexual, the, all", his, clearly, =|>, advantage,
# Nearest to as: very, PIT,, when, so, and, As, since, like,
# Nearest to you: we, they, I, someone, people, it, You, he,
# Nearest to I'm: you're, it's, am, they're, I, tools., it, Wide,
# Nearest to been: had, was, be, already, were, also, seen, got,
# Average loss at step  72000 :  5.35340685445
# Average loss at step  74000 :  5.0405267297
# Average loss at step  76000 :  4.82371885931
# Average loss at step  78000 :  4.92620084882
# Average loss at step  80000 :  4.77880743933
# Nearest to only: 15$, also, no, probably, best, students, anybody, next,
# Nearest to that: which, what, ../.././lib/Xmu/libXmu.a, also, EQU, <o&o, [==], and,
# Nearest to would: will, should, can, could, may, must, might, didn't,
# Nearest to can: will, could, should, would, cannot, may, might, can't,
# Nearest to at: in, from, on, invasion,, after, over, into, for,
# Nearest to has: had, is, was, have, does, I've, 'hacker', were,
# Nearest to use: make, end, individuals, /--, convert, 0.067, kill, read,
# Nearest to Organization:: Nntp-Posting-Host:, Reply-To:, Distribution:, Achkar), talk.politics.guns, State, other;, 75.6,
# Nearest to your: my, his, their, the, our, any, its, this,
# Nearest to we: they, you, I, he, You, We, i, it,
# Nearest to -: 00-00, [==], MVI, /lib/libX11.so, , kt>, Winner, champ,,
# Nearest to an: Sexual, your, all", the, clearly, Church,, CUP, advantage,
# Nearest to as: very, PIT,, when, As, so, and, since, 15$,
# Nearest to you: we, they, I, someone, people, You, it, he,
# Nearest to I'm: you're, it's, am, they're, tools., I, It's, initially,
# Nearest to been: had, be, was, already, were, got, seen, also,
# Average loss at step  82000 :  23.140049644
# Average loss at step  84000 :  5.15997224629
# Average loss at step  86000 :  6.54397142363
# Average loss at step  88000 :  4.90989547467
# Average loss at step  90000 :  4.86869128585
# Nearest to only: 15$, also, no, best, probably, students, /lib/libX11.so, >rh>,
# Nearest to that: which, what, <o&o, also, >that, EQU, ../.././lib/Xmu/libXmu.a, 75.6,
# Nearest to would: will, should, could, can, may, must, might, cannot,
# Nearest to can: could, will, should, would, cannot, may, can't, might,
# Nearest to at: in, on, from, over, into, after, when, invasion,,
# Nearest to has: had, have, is, was, 'hacker', does, -$10, Michelle,
# Nearest to use: end, make, individuals, Siemens-Nixdorf, convert, kill, 0.067, read,
# Nearest to Organization:: Nntp-Posting-Host:, Reply-To:, Distribution:, Achkar), talk.politics.guns, State, other;, takes.,
# Nearest to your: my, his, their, our, the, any, its, this,
# Nearest to we: they, you, I, he, You, We, i, it,
# Nearest to -: 00-00, MVI, , /lib/libX11.so, [==], STA, 0.00, Winner,
# Nearest to an: Sexual, the, all", your, yearly, clearly, CUP, sez;,
# Nearest to as: when, very, and, PIT,, in, As, since, so,
# Nearest to you: we, they, I, someone, You, there, it, he,
# Nearest to I'm: you're, it's, they're, am, It's, I, tools., he's,
# Nearest to been: had, be, was, already, were, got, seen, also,
# Average loss at step  92000 :  17.0806910854
# Average loss at step  94000 :  5.24162190241
# Average loss at step  96000 :  4.64577683577
# Average loss at step  98000 :  6.0891728977
# Average loss at step  100000 :  11.9719069982
# Nearest to only: 15$, also, best, students, no, probably, anybody, >rh>,
# Nearest to that: which, what, EQU, >that, ../.././lib/Xmu/libXmu.a, <o&o, also, 75.6,
# Nearest to would: will, should, could, can, may, must, might, didn't,
# Nearest to can: could, will, should, would, cannot, may, can't, might,
# Nearest to at: in, on, from, invasion,, after, over, requested., invoke,
# Nearest to has: had, is, was, have, does, 'hacker', I've, raid?,
# Nearest to use: end, individuals, make, convert, kill, /--, 0.067, UNK,
# Nearest to Organization:: Nntp-Posting-Host:, Reply-To:, Distribution:, Achkar), State, talk.politics.guns, other;, Lines:,
# Nearest to your: my, his, their, our, the, any, its, a,
# Nearest to we: they, you, I, he, We, You, i, there,
# Nearest to -: 00-00, MVI, , g3states.h, 0.00, Winner, [==], champ,,
# Nearest to an: Sexual, all", yearly, CUP, your, advantage, StyleWriter, clearly,
# Nearest to as: very, when, As, PIT,, in, since, so, MVI,
# Nearest to you: we, they, I, someone, people, You, i, there,
# Nearest to I'm: you're, it's, they're, am, I, It's, he's, tools.,
# Nearest to been: had, be, already, was, were, got, jmh@hopper.Virginia.EDU, seen,
