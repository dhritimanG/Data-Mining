# %%
"""Basic word2vec example."""

from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import sys
import argparse
import random
from tempfile import gettempdir
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

from tensorflow.contrib.tensorboard.plugins import projector

# Give a folder path as an argument with '--log_dir' to save
# TensorBoard summaries. Default is a log folder in current directory.
current_path = '/Users/dhritiman/.spyder'

parser = argparse.ArgumentParser()
parser.add_argument(
    '--log_dir',
    type=str,
    default=os.path.join(current_path, 'log'),
    help='The log directory for TensorBoard summaries.')
FLAGS, unparsed = parser.parse_known_args()

# Create the directory for TensorBoard variables if there is not.
if not os.path.exists(FLAGS.log_dir):
  os.makedirs(FLAGS.log_dir)

# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'


# pylint: disable=redefined-outer-name
def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  local_filename = os.path.join(gettempdir(), filename)
  if not os.path.exists(local_filename):
    local_filename, _ = urllib.request.urlretrieve(url + filename,
                                                   local_filename)
  statinfo = os.stat(local_filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception('Failed to verify ' + local_filename +
                    '. Can you get to it with a browser?')
  return local_filename


filename = maybe_download('text8.zip', 31344016)


# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words."""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data


vocabulary = read_data(filename)
print('Data size', len(vocabulary))

# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000


def build_dataset(words, n_words):
  """Process raw inputs into a dataset."""
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(n_words - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    index = dictionary.get(word, 0)
    if index == 0:  # dictionary['UNK']
      unk_count += 1
    data.append(index)
  count[0][1] = unk_count
  reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
  return data, count, dictionary, reversed_dictionary


# Filling 4 global variables:
# data - list of codes (integers from 0 to vocabulary_size-1).
#   This is the original text but words are replaced by their codes
# count - map of words(strings) to count of occurrences
# dictionary - map of words(strings) to their codes(integers)
# reverse_dictionary - maps codes(integers) to words(strings)
data, count, dictionary, reverse_dictionary = build_dataset(
    vocabulary, vocabulary_size)
del vocabulary  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

data_index = 0


# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1  # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)  # pylint: disable=redefined-builtin
  if data_index + span > len(data):
    data_index = 0
  buffer.extend(data[data_index:data_index + span])
  data_index += span
  for i in range(batch_size // num_skips):
    context_words = [w for w in range(span) if w != skip_window]
    words_to_use = random.sample(context_words, num_skips)
    for j, context_word in enumerate(words_to_use):
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[context_word]
    if data_index == len(data):
      buffer.extend(data[0:span])
      data_index = span
    else:
      buffer.append(data[data_index])
      data_index += 1
  # Backtrack a little bit to avoid skipping words in the end of a batch
  data_index = (data_index + len(data) - span) % len(data)
  return batch, labels


batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
  print(batch[i], reverse_dictionary[batch[i]], '->', labels[i, 0],
        reverse_dictionary[labels[i, 0]])

# Step 4: Build and train a skip-gram model.

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1  # How many words to consider left and right.
num_skips = 2  # How many times to reuse an input to generate a label.
num_sampled = 64  # Number of negative examples to sample.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. These 3 variables are used only for
# displaying model accuracy, they don't affect calculation.
valid_size = 16  # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)

graph = tf.Graph()

with graph.as_default():

  # Input data.
  with tf.name_scope('inputs'):
    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

  # Ops and variables pinned to the CPU because of missing GPU implementation
  with tf.device('/cpu:0'):
    # Look up embeddings for inputs.
    with tf.name_scope('embeddings'):
      embeddings = tf.Variable(
          tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
      embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Construct the variables for the NCE loss
    with tf.name_scope('weights'):
      nce_weights = tf.Variable(
          tf.truncated_normal(
              [vocabulary_size, embedding_size],
              stddev=1.0 / math.sqrt(embedding_size)))
    with tf.name_scope('biases'):
      nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

  # Compute the average NCE loss for the batch.
  # tf.nce_loss automatically draws a new sample of the negative labels each
  # time we evaluate the loss.
  # Explanation of the meaning of NCE loss:
  #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
  with tf.name_scope('loss'):
    loss = tf.reduce_mean(
        tf.nn.nce_loss(
            weights=nce_weights,
            biases=nce_biases,
            labels=train_labels,
            inputs=embed,
            num_sampled=num_sampled,
            num_classes=vocabulary_size))

  # Add the loss value as a scalar to summary.
  tf.summary.scalar('loss', loss)

  # Construct the SGD optimizer using a learning rate of 1.0.
  with tf.name_scope('optimizer'):
    optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

  # Compute the cosine similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings,
                                            valid_dataset)
  similarity = tf.matmul(
      valid_embeddings, normalized_embeddings, transpose_b=True)

  # Merge all summaries.
  merged = tf.summary.merge_all()

  # Add variable initializer.
  init = tf.global_variables_initializer()

  # Create a saver.
  saver = tf.train.Saver()

# Step 5: Begin training.
num_steps = 100001

with tf.Session(graph=graph) as session:
  # Open a writer to write summaries.
  writer = tf.summary.FileWriter(FLAGS.log_dir, session.graph)

  # We must initialize all variables before we use them.
  init.run()
  print('Initialized')

  average_loss = 0
  for step in xrange(num_steps):
    batch_inputs, batch_labels = generate_batch(batch_size, num_skips,
                                                skip_window)
    feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

    # Define metadata variable.
    run_metadata = tf.RunMetadata()

    # We perform one update step by evaluating the optimizer op (including it
    # in the list of returned values for session.run()
    # Also, evaluate the merged op to get all summaries from the returned "summary" variable.
    # Feed metadata variable to session for visualizing the graph in TensorBoard.
    _, summary, loss_val = session.run(
        [optimizer, merged, loss],
        feed_dict=feed_dict,
        run_metadata=run_metadata)
    average_loss += loss_val

    # Add returned summaries to writer in each step.
    writer.add_summary(summary, step)
    # Add metadata to visualize the graph for the last run.
    if step == (num_steps - 1):
      writer.add_run_metadata(run_metadata, 'step%d' % step)

    if step % 2000 == 0:
      if step > 0:
        average_loss /= 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step ', step, ': ', average_loss)
      average_loss = 0

    # Note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8  # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
        log_str = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log_str = '%s %s,' % (log_str, close_word)
        print(log_str)
  final_embeddings = normalized_embeddings.eval()

  # Write corresponding labels for the embeddings.
  with open(FLAGS.log_dir + '/metadata.tsv', 'w') as f:
    for i in xrange(vocabulary_size):
      f.write(reverse_dictionary[i] + '\n')

  # Save the model for checkpoints.
  saver.save(session, os.path.join(FLAGS.log_dir, 'model.ckpt'))

  # Create a configuration for visualizing embeddings with the labels in TensorBoard.
  config = projector.ProjectorConfig()
  embedding_conf = config.embeddings.add()
  embedding_conf.tensor_name = embeddings.name
  embedding_conf.metadata_path = os.path.join(FLAGS.log_dir, 'metadata.tsv')
  projector.visualize_embeddings(writer, config)

writer.close()

# Step 6: Visualize the embeddings.


# pylint: disable=missing-docstring
# Function to draw visualization of distance between embeddings.
def plot_with_labels(low_dim_embs, labels, filename):
  assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
  plt.figure(figsize=(18, 18))  # in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i, :]
    plt.scatter(x, y)
    plt.annotate(
        label,
        xy=(x, y),
        xytext=(5, 2),
        textcoords='offset points',
        ha='right',
        va='bottom')

  plt.savefig(filename)


try:
  # pylint: disable=g-import-not-at-top
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(
      perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
  plot_only = 500
  low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
  labels = [reverse_dictionary[i] for i in xrange(plot_only)]
  plot_with_labels(low_dim_embs, labels, os.path.join(gettempdir(), 'tsne.png'))

except ImportError as ex:
  print('Please install sklearn, matplotlib, and scipy to show embeddings.')
  print(ex)
# Out:
# Found and verified text8.zip
# Data size 17005207
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
# 3081 originated -> 5234 anarchism
# 3081 originated -> 12 as
# 12 as -> 3081 originated
# 12 as -> 6 a
# 6 a -> 195 term
# 6 a -> 12 as
# 195 term -> 6 a
# 195 term -> 2 of
# Initialized
# Average loss at step  0 :  294.930114746
# Nearest to their: stahl, modalities, satisfiability, breton, zout, inanimate, flatus, alligator,
# Nearest to or: deliberation, domestication, bestseller, dama, imperatoribus, gand, isidore, carboxylic,
# Nearest to i: rtl, raves, dispense, biologically, gamete, covalently, ohrid, humanity,
# Nearest to called: puzo, theravada, qualifier, texaco, sola, ethically, reliability, arrangements,
# Nearest to two: skim, judaeo, cuttlefish, segregated, noises, branko, og, derry,
# Nearest to only: moves, authenticated, gaspard, nextel, gules, fervor, anus, hohmann,
# Nearest to into: monument, aerodynamics, tet, astrophysicists, pagans, marcellus, wilhelmina, continuum,
# Nearest to state: timurid, planing, saturday, wife, bud, canonically, lounge, prem,
# Nearest to first: vulgar, reply, rowan, eyebrows, farnsworth, blog, acura, ceramics,
# Nearest to there: disparaging, panhandle, lower, instinctive, bari, renegade, calculate, qinghai,
# Nearest to four: any, fed, arising, eldr, linnaean, jagged, klement, benefiting,
# Nearest to also: relaunch, vigour, military, ambivalent, pasture, brazilian, predictor, jonson,
# Nearest to of: curly, ideologies, propeller, commemorating, bioleaching, external, cimmerians, sheffield,
# Nearest to most: franco, democratically, johansen, harassed, insignificant, renarrative, caribs, teens,
# Nearest to nine: maker, publishers, srpska, widowers, screenwriters, parmenides, adoption, gigs,
# Nearest to five: satanic, penguin, bret, cedar, gateways, guanaco, agee, imbolc,
# Average loss at step  2000 :  112.886721173
# Average loss at step  4000 :  52.774921454
# Average loss at step  6000 :  33.7954548746
# Average loss at step  8000 :  23.6340183258
# Average loss at step  10000 :  17.9790283638
# Nearest to their: the, purity, letter, its, dental, bckgr, roles, wright,
# Nearest to or: and, UNK, in, s, of, soroban, melody, a,
# Nearest to i: utilitarian, who, stretches, industry, humanity, clean, stylized, vocabulary,
# Nearest to called: friendly, reliability, counties, reference, roddick, arrangements, vector, mosque,
# Nearest to two: one, nine, four, gb, vs, canaris, three, cardinality,
# Nearest to only: psi, moves, coke, cultivated, break, prepared, nine, smell,
# Nearest to into: monument, in, with, forever, canaris, aerodynamics, dynastic, minority,
# Nearest to state: wife, saturday, kentucky, life, mystic, sum, rendered, spacecraft,
# Nearest to first: from, cannot, drivers, tuna, tubing, analyst, reply, thing,
# Nearest to there: who, disparaging, lower, panhandle, tone, cardinality, pressure, calculate,
# Nearest to four: nine, two, three, five, one, six, frames, disambiguation,
# Nearest to also: affected, broke, military, vs, which, austin, influenced, sovereignty,
# Nearest to of: in, and, for, agave, aarhus, on, the, with,
# Nearest to most: franco, align, teens, terrain, compounds, company, judo, sentence,
# Nearest to nine: zero, eight, psi, six, gland, one, two, coke,
# Nearest to five: zero, nine, six, seven, soroban, eight, four, bckgr,
# Average loss at step  12000 :  13.9730161898
# Average loss at step  14000 :  11.5980560554
# Average loss at step  16000 :  9.92747251356
# Average loss at step  18000 :  8.51025679255
# Average loss at step  20000 :  8.20652107179
# Nearest to their: the, its, purity, his, letter, wright, oft, dasyprocta,
# Nearest to or: and, agouti, for, UNK, s, hbox, in, dasyprocta,
# Nearest to i: utilitarian, circ, who, humanity, industry, stretches, proclamation, vocabulary,
# Nearest to called: reliability, friendly, counties, arrangements, vector, reference, destroying, ethically,
# Nearest to two: one, four, three, circ, five, six, nine, operatorname,
# Nearest to only: psi, cultivated, inches, circ, prepared, moves, nine, homer,
# Nearest to into: with, in, marcellus, monument, by, forever, dynastic, contemplate,
# Nearest to state: brahma, wife, saturday, kentucky, life, operatorname, shirkuh, sum,
# Nearest to first: polynomials, from, anagrams, operatorname, drivers, sentence, UNK, rowan,
# Nearest to there: who, it, disparaging, lower, ensemble, they, cardinality, bari,
# Nearest to four: three, six, five, two, eight, nine, zero, seven,
# Nearest to also: which, allosaurus, affected, broke, not, military, microorganisms, aphrodite,
# Nearest to of: in, and, for, dasyprocta, zero, operatorname, nine, with,
# Nearest to most: franco, teens, align, company, treated, compounds, continent, soprano,
# Nearest to nine: eight, six, zero, seven, five, dasyprocta, circ, four,
# Nearest to five: eight, nine, zero, six, seven, four, two, circ,
# Average loss at step  22000 :  7.01099583316
# Average loss at step  24000 :  6.86789237678
# Average loss at step  26000 :  6.72341370761
# Average loss at step  28000 :  6.32647135007
# Average loss at step  30000 :  5.91557120216
# Nearest to their: its, the, his, abet, purity, dasyprocta, sonatas, sony,
# Nearest to or: and, dek, agouti, dasyprocta, six, hbox, for, gland,
# Nearest to i: utilitarian, who, circ, humanity, proclamation, industry, biologically, vocabulary,
# Nearest to called: reliability, azad, friendly, counties, arrangements, darling, vector, theravada,
# Nearest to two: four, three, six, one, five, seven, circ, eight,
# Nearest to only: psi, inches, abet, cultivated, prepared, nine, mishnayot, aorta,
# Nearest to into: with, by, in, marcellus, monument, forever, dynastic, hell,
# Nearest to state: wife, brahma, saturday, kentucky, operatorname, UNK, pitt, shirkuh,
# Nearest to first: polynomials, operatorname, abakan, drivers, from, sentence, anagrams, gte,
# Nearest to there: who, it, they, disparaging, he, cardinality, ensemble, bari,
# Nearest to four: five, six, eight, three, two, seven, nine, zero,
# Nearest to also: which, not, it, never, that, affected, tonnage, who,
# Nearest to of: and, in, for, nine, dasyprocta, eight, from, seven,
# Nearest to most: franco, teens, treated, align, beckett, soprano, company, administrative,
# Nearest to nine: eight, six, seven, five, four, zero, circ, dasyprocta,
# Nearest to five: six, eight, four, seven, nine, zero, two, three,
# Average loss at step  32000 :  5.9794507668
# Average loss at step  34000 :  5.67738172841
# Average loss at step  36000 :  5.78382994163
# Average loss at step  38000 :  5.52927557456
# Average loss at step  40000 :  5.23301912469
# Nearest to their: its, the, his, abet, purity, dasyprocta, sonatas, bajan,
# Nearest to or: and, dek, agouti, zero, dasyprocta, operatorname, hbox, aveiro,
# Nearest to i: who, cleric, utilitarian, proclamation, kilowatt, circ, covalently, dividend,
# Nearest to called: reliability, azad, friendly, darling, counties, arrangements, vector, hasan,
# Nearest to two: three, one, four, five, six, eight, seven, circ,
# Nearest to only: psi, abet, inches, cultivated, ratites, mishnayot, aveiro, prepared,
# Nearest to into: with, in, marcellus, by, from, monument, hell, dynastic,
# Nearest to state: wife, brahma, saturday, kentucky, shirkuh, operatorname, pitt, seinfeld,
# Nearest to first: polynomials, acura, operatorname, sentence, abakan, drivers, recitative, waterloo,
# Nearest to there: it, who, they, he, disparaging, sometimes, still, ensemble,
# Nearest to four: five, six, three, eight, seven, two, zero, one,
# Nearest to also: which, not, never, that, it, who, tonnage, foliage,
# Nearest to of: in, zero, dasyprocta, and, agouti, arin, operatorname, eight,
# Nearest to most: franco, nuke, align, treated, all, beckett, teens, emphasising,
# Nearest to nine: eight, seven, six, zero, five, four, circ, dasyprocta,
# Nearest to five: six, four, eight, three, seven, zero, nine, two,
# Average loss at step  42000 :  5.36082036233
# Average loss at step  44000 :  5.23764634717
# Average loss at step  46000 :  5.20184326005
# Average loss at step  48000 :  5.21960247815
# Average loss at step  50000 :  4.98360522902
# Nearest to their: its, his, the, outfielders, abet, her, dasyprocta, axles,
# Nearest to or: and, kapoor, agouti, four, eight, three, dek, six,
# Nearest to i: who, cleric, proclamation, kilowatt, covalently, circ, dividend, utilitarian,
# Nearest to called: azad, reliability, darling, friendly, and, counties, estuary, hasan,
# Nearest to two: three, four, one, six, five, seven, eight, circ,
# Nearest to only: ratites, inches, abet, mishnayot, four, psi, but, aveiro,
# Nearest to into: with, from, marcellus, in, by, monument, hell, dynastic,
# Nearest to state: brahma, wife, kentucky, saturday, shirkuh, pitt, seinfeld, finger,
# Nearest to first: polynomials, second, waterloo, recitative, four, drivers, operatorname, sentence,
# Nearest to there: it, they, who, he, still, disparaging, sometimes, repulsed,
# Nearest to four: three, six, five, eight, seven, two, one, circ,
# Nearest to also: which, never, not, often, it, who, usually, that,
# Nearest to of: in, eight, dasyprocta, arin, for, agouti, nine, operatorname,
# Nearest to most: johansen, franco, treated, all, align, beckett, administrative, nuke,
# Nearest to nine: eight, six, seven, zero, three, five, dasyprocta, four,
# Nearest to five: six, four, three, seven, eight, two, circ, zero,
# Average loss at step  52000 :  5.05543565655
# Average loss at step  54000 :  5.18658621466
# Average loss at step  56000 :  5.04023350811
# Average loss at step  58000 :  5.06548312032
# Average loss at step  60000 :  4.95529236853
# Nearest to their: its, his, the, outfielders, her, abet, concentrate, dasyprocta,
# Nearest to or: and, thibetanus, kapoor, ursus, agouti, five, four, six,
# Nearest to i: rtl, cleric, who, ursus, proclamation, pu, kilowatt, ii,
# Nearest to called: azad, reliability, darling, friendly, estuary, counties, hasan, inspirations,
# Nearest to two: three, four, one, five, six, circ, ursus, eight,
# Nearest to only: but, inches, ursus, ratites, mishnayot, abet, prepared, five,
# Nearest to into: with, from, marcellus, in, monument, hell, by, lycaon,
# Nearest to state: brahma, kentucky, wife, shirkuh, operatorname, saturday, finger, ursus,
# Nearest to first: polynomials, second, ursus, recitative, waterloo, drivers, abakan, operatorname,
# Nearest to there: it, they, who, he, still, repulsed, which, sometimes,
# Nearest to four: six, five, eight, three, seven, two, nine, ursus,
# Nearest to also: which, never, often, it, that, not, ursus, now,
# Nearest to of: in, and, nine, ursus, dasyprocta, for, eight, wct,
# Nearest to most: johansen, michelob, franco, all, some, treated, align, administrative,
# Nearest to nine: eight, six, seven, four, zero, five, ursus, circ,
# Nearest to five: four, six, three, eight, seven, ursus, two, nine,
# Average loss at step  62000 :  5.03621928489
# Average loss at step  64000 :  4.85309439027
# Average loss at step  66000 :  4.60417861593
# Average loss at step  68000 :  4.99726367354
# Average loss at step  70000 :  4.89476782799
# Nearest to their: its, his, the, her, outfielders, abet, microcebus, some,
# Nearest to or: and, cebus, thibetanus, kapoor, ursus, agouti, thaler, but,
# Nearest to i: rtl, cleric, who, proclamation, ii, ursus, we, pu,
# Nearest to called: azad, reliability, darling, friendly, estuary, hasan, inspirations, UNK,
# Nearest to two: three, four, six, five, eight, one, seven, ursus,
# Nearest to only: but, inches, ursus, mishnayot, abet, microcebus, ratites, montju,
# Nearest to into: from, with, marcellus, by, hell, monument, embroidery, lycaon,
# Nearest to state: brahma, finger, wife, kentucky, saturday, operatorname, microcebus, shirkuh,
# Nearest to first: second, polynomials, ursus, microcebus, recitative, cebus, operatorname, story,
# Nearest to there: it, they, he, who, still, repulsed, sometimes, which,
# Nearest to four: six, five, three, eight, seven, two, nine, ursus,
# Nearest to also: which, never, often, now, thaler, it, ursus, not,
# Nearest to of: cebus, dasyprocta, agouti, ursus, microcebus, and, for, wct,
# Nearest to most: johansen, upanija, michelob, some, all, many, treated, franco,
# Nearest to nine: eight, seven, six, five, four, three, zero, ursus,
# Nearest to five: six, four, three, eight, seven, two, nine, zero,
# Average loss at step  72000 :  4.7498378737
# Average loss at step  74000 :  4.81396814871
# Average loss at step  76000 :  4.72805220532
# Average loss at step  78000 :  4.79860770229
# Average loss at step  80000 :  4.82001258856
# Nearest to their: its, his, the, her, outfielders, abet, microcebus, concentrate,
# Nearest to or: and, cebus, thibetanus, kapoor, ursus, iit, agouti, busan,
# Nearest to i: rtl, cleric, ursus, we, ii, who, proclamation, pu,
# Nearest to called: azad, darling, reliability, friendly, cebus, estuary, hasan, vacation,
# Nearest to two: three, four, six, five, one, seven, eight, circ,
# Nearest to only: but, inches, mishnayot, ursus, abet, microcebus, ratites, busan,
# Nearest to into: from, with, marcellus, by, monument, lycaon, hell, embroidery,
# Nearest to state: finger, dominion, brahma, kentucky, sayfawa, wife, microcebus, operatorname,
# Nearest to first: second, polynomials, ursus, microcebus, pontificia, during, recitative, story,
# Nearest to there: it, they, he, still, who, repulsed, sometimes, which,
# Nearest to four: six, five, seven, three, eight, two, zero, nine,
# Nearest to also: which, often, never, now, still, it, usually, ursus,
# Nearest to of: cebus, in, ursus, wct, microcebus, thaler, dasyprocta, nine,
# Nearest to most: johansen, some, many, upanija, michelob, more, all, treated,
# Nearest to nine: eight, six, seven, four, five, zero, ursus, microcebus,
# Nearest to five: six, four, seven, eight, three, zero, two, nine,
# Average loss at step  82000 :  4.76149710953
# Average loss at step  84000 :  4.76089461112
# Average loss at step  86000 :  4.77160685503
# Average loss at step  88000 :  4.73993606365
# Average loss at step  90000 :  4.74195808816
# Nearest to their: its, his, the, her, outfielders, microcebus, some, abet,
# Nearest to or: and, thibetanus, cebus, kapoor, ursus, agouti, busan, iit,
# Nearest to i: rtl, ii, cleric, we, ursus, UNK, pu, who,
# Nearest to called: azad, darling, reliability, UNK, considered, estuary, friendly, cebus,
# Nearest to two: three, four, one, six, five, seven, eight, circ,
# Nearest to only: but, inches, mishnayot, ursus, abet, microcebus, even, ratites,
# Nearest to into: from, with, marcellus, through, hell, by, lycaon, monument,
# Nearest to state: dominion, finger, brahma, kentucky, sayfawa, microcebus, operatorname, wife,
# Nearest to first: second, polynomials, ursus, pontificia, microcebus, story, next, waterloo,
# Nearest to there: they, it, he, still, repulsed, who, sometimes, microcebus,
# Nearest to four: five, three, seven, six, eight, two, one, zero,
# Nearest to also: often, which, never, now, still, usually, not, ursus,
# Nearest to of: cebus, iit, in, including, arin, dasyprocta, microcebus, agouti,
# Nearest to most: johansen, some, more, many, michelob, upanija, treated, use,
# Nearest to nine: eight, seven, six, five, four, zero, three, ursus,
# Nearest to five: four, seven, eight, six, three, zero, nine, ursus,
# Average loss at step  92000 :  4.66639748573
# Average loss at step  94000 :  4.72941469193
# Average loss at step  96000 :  4.68526105237
# Average loss at step  98000 :  4.58318847728
# Average loss at step  100000 :  4.68975115466
# Nearest to their: its, his, the, her, some, microcebus, outfielders, abet,
# Nearest to or: and, thibetanus, cebus, kapoor, ursus, agouti, iit, busan,
# Nearest to i: rtl, we, ii, cleric, ursus, pu, you, six,
# Nearest to called: azad, darling, reliability, considered, cebus, estuary, friendly, gelasian,
# Nearest to two: four, three, five, six, one, seven, eight, circ,
# Nearest to only: mishnayot, but, inches, three, ursus, even, microcebus, abet,
# Nearest to into: from, with, marcellus, through, in, under, monument, pagans,
# Nearest to state: dominion, finger, brahma, kentucky, microcebus, sayfawa, congress, operatorname,
# Nearest to first: second, polynomials, next, ursus, story, pontificia, last, under,
# Nearest to there: it, they, he, still, repulsed, sometimes, this, but,
# Nearest to four: five, seven, three, six, eight, two, zero, ursus,
# Nearest to also: often, which, never, now, still, usually, not, ursus,
# Nearest to of: including, cebus, in, iit, agouti, ursus, and, wct,
# Nearest to most: johansen, some, more, many, michelob, upanija, treated, use,
# Nearest to nine: eight, seven, six, five, zero, four, three, ursus,
# Nearest to five: four, seven, three, six, eight, two, zero, nine,
